# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#https://drive.google.com/file/d/15rEaadRHM5-J73zen32LZU8Mo7luW1Hk/view?usp=sharing
df = pd.read_parquet("https://drive.google.com/uc?id=15rEaadRHM5-J73zen32LZU8Mo7luW1Hk")

# %%
df.head(10)
# Out:
#    NU_INSCRICAO  NU_ANO  TP_SEXO  TP_FAIXA_ETARIA  TP_ESTADO_CIVIL  \
# 0  190001004651    2019        0                3                1
# 1  190001004662    2019        1                2                1
# 2  190001004736    2019        0                3                1
# 3  190001004926    2019        0               12                1
# 4  190001005145    2019        1               11                2
# 5  190001005193    2019        0                8                1
# 6  190001005261    2019        1               13                2
# 7  190001005284    2019        0                4                1
# 8  190001005310    2019        0                2                1
# 9  190001005452    2019        0                2                1
#
#    TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  TP_ESCOLA  \
# 0            3                 1                2                0          2
# ...

# %%
df.columns
# Out:
# Index(['NU_INSCRICAO', 'NU_ANO', 'TP_SEXO', 'TP_FAIXA_ETARIA',
#        'TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_NACIONALIDADE', 'TP_ST_CONCLUSAO',
#        'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO', 'IN_TREINEIRO',
#        'CO_MUNICIPIO_ESC', 'SG_UF_ESC', 'TP_DEPENDENCIA_ADM_ESC',
#        'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC', 'TP_PRESENCA_CN',
#        'TP_PRESENCA_CH', 'TP_PRESENCA_LC', 'TP_PRESENCA_MT', 'CO_PROVA_CN',
#        'CO_PROVA_CH', 'CO_PROVA_LC', 'CO_PROVA_MT', 'NU_NOTA_CN', 'NU_NOTA_CH',
#        'NU_NOTA_LC', 'NU_NOTA_MT', 'TX_RESPOSTAS_CN', 'TX_RESPOSTAS_CH',
#        'TX_RESPOSTAS_LC', 'TX_RESPOSTAS_MT', 'TP_LINGUA', 'TP_STATUS_REDACAO',
#        'NU_NOTA_COMP1', 'NU_NOTA_COMP2', 'NU_NOTA_COMP3', 'NU_NOTA_COMP4',
#        'NU_NOTA_COMP5', 'NU_NOTA_REDACAO', 'Q001', 'Q002', 'Q003', 'Q004',
#        'Q005', 'Q006', 'Q007', 'Q008', 'Q009', 'Q010', 'Q011', 'Q012', 'Q013',
#        'Q014', 'Q015', 'Q016', 'Q017', 'Q018', 'Q019', 'Q020', 'Q021', 'Q022',
# ...
